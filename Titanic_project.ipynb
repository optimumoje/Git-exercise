# %% [markdown]
# ## Problem statement: Explore the titanic dataset, and do some EDA and Data Cleaning.
# >>>>Dataset was  gottten from kaggle.
#
# >>>Add a touch of ML.
#
# >>OmoOje

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
titanic= pd.read_csv("C:\\Users\\Ope\\Documents\\workable_csv_e\\Titanic-Dataset.csv")
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Let's check for missing values
missing = titanic.isnull().sum()
missing = missing[missing>0]
missing.sort_values(inplace=True)
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Now let's drop what is not needed!
# titanic=df.drop(['PassengerId', 'Name' , 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis=1)
# titanic

# %% [markdown]
# ## Let's handle our missing values

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## from above we can see that Age dtype is float with values like 40.5,  0.67.

# %%
# Filling missing values in Age column with median and turn the colum to int

titanic['Age'] = titanic.Age.fillna(titanic.Age.median()).astype(int)

# %%
titanic.head(20).T
# Out:
#                                   0   \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                             1   \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
titanic.Age.unique()
# Out:
# array([22, 38, 26, 35, 28, 54,  2, 27, 14,  4, 58, 20, 39, 55, 31, 34, 15,
#         8, 19, 40, 66, 42, 21, 18,  3,  7, 49, 29, 65,  5, 11, 45, 17, 32,
#        16, 25,  0, 30, 33, 23, 24, 46, 59, 71, 37, 47, 70, 12,  9, 36, 51,
#        44,  1, 61, 56, 50, 62, 41, 52, 63, 43, 60, 10, 64, 13, 48, 53, 57,
#        80,  6, 74])

# %%
titanic.loc[titanic.Age==40]
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 40            41         0       3
# 153          154         0       3
# 161          162         1       2
# 188          189         0       3
# 209          210         1       1
# 263          264         0       1
# 319          320         1       1
# 346          347         1       2
# 360          361         0       3
# 525          526         0       3
# 561          562         0       3
# 609          610         1       1
# 661          662         0       3
# 670          671         1       2
#
#                                                   Name     Sex  Age  SibSp  \
# 30                            Uruchurtu, Don. Manuel E    male   40      0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female   40      1
# 153                    van Billiard, Mr. Austin Blyler    male   40      0
# 161  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female   40      0
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.boxplot(data =titanic.Age)
# Out:
# <AxesSubplot:>

# %%
# The outliers above will not be removed because boarding a ship is not age_bound.

# %%
#fig = 
titanic.groupby(['Sex']).sum().plot(kind= 'pie', y= 'Survived', autopct = '%1.0f%%', explode=(0.05, 0.05))
# Out:
# <AxesSubplot:ylabel='Survived'>

# %% [markdown]
# ## This shows that 68% of survivors are female...such is life...Guys look after yourself too...):

# %%
targ= titanic.Survived.value_counts()
targ.plot(kind='bar', color=['salmon', 'lightblue']);

# %%
SS = pd.crosstab(titanic.Sex, titanic.Survived)
SS
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
sns.countplot(x = titanic.Sex, hue= titanic.Survived, data = titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = titanic.Age.value_counts(), hue= titanic.Survived, data = titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
inputs = titanic.drop('Survived', axis=1)
target = titanic.Survived

# %%
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})
inputs.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex  Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    1   22      1      0         A/5 21171   7.2500   NaN        S
# 1    2   38      1      0          PC 17599  71.2833   C85        C
# 2    2   26      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    2   35      1      0            113803  53.1000  C123        S
# 4    1   35      0      0            373450   8.0500   NaN        S

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(inputs, target, test_size=0.2)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(x_train.values, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 model.fit(x_train.values, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# ...

# %%
model.score(x_test.values, y_test)

# %%
model.predict([[3,0,50,8]])

# %%
model.predict(x_test.values);

# %%
y_predicted =model.predict(x_test.values)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_predicted, y_test)

# %%
plt.figure(figsize=(10,5))
import seaborn as sns
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth');
